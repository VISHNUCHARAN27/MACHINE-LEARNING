# %% [markdown]
# <a href="https://colab.research.google.com/github/VISHNUCHARAN27/MACHINE-LEARNING/blob/master/BikeSharing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/train.csv')
df
# Out:
#                   datetime  season  holiday  ...  casual  registered  count
# 0      2011-01-01 00:00:00       1        0  ...       3          13     16
# 1      2011-01-01 01:00:00       1        0  ...       8          32     40
# 2      2011-01-01 02:00:00       1        0  ...       5          27     32
# 3      2011-01-01 03:00:00       1        0  ...       3          10     13
# 4      2011-01-01 04:00:00       1        0  ...       0           1      1
# 5      2011-01-01 05:00:00       1        0  ...       0           1      1
# 6      2011-01-01 06:00:00       1        0  ...       2           0      2
# 7      2011-01-01 07:00:00       1        0  ...       1           2      3
# 8      2011-01-01 08:00:00       1        0  ...       1           7      8
# 9      2011-01-01 09:00:00       1        0  ...       8           6     14
# 10     2011-01-01 10:00:00       1        0  ...      12          24     36
# ...

# %%
df.count()
# Out:
# datetime      10886
# season        10886
# holiday       10886
# workingday    10886
# weather       10886
# temp          10886
# atemp         10886
# humidity      10886
# windspeed     10886
# casual        10886
# registered    10886
# count         10886
# dtype: int64

# %%
x=df.isnull().values
x.any()
# Out:
# False

# %%
import matplotlib.pyplot as plt
plt.scatter(df['temp'],df['atemp'])
plt.xlabel('temp')
plt.ylabel('atemp')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['temp'],df['humidity'])
plt.xlabel('temp')
plt.ylabel('humidity')
plt.show()

# %%
plt.bar(df['season'],df['temp'])
plt.xlabel('season')
plt.ylabel('temp')
plt.show()

# %%
x=(df['season'].value_counts())

# %%
x
# Out:
# 4    2734
# 3    2733
# 2    2733
# 1    2686
# Name: season, dtype: int64

# %%
x[1]
# Out:
# 2686

# %%
seasons=['spring','summer', 'fall','winter' ]
plt.bar(seasons,x,color='pink')
plt.xlabel('season')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize=(10,5))
t=df['weather'].value_counts()
weather_names=['Clear,Few clouds','Mist & Cloudy,Broken clouds','Light Snow & Rain','Heavy Rain & Ice Pallets']
plt.bar(weather_names,t,color='green',align='center')
plt.xlabel('weather')
plt.ylabel('count')
plt.show()

# %%
t
# Out:
# 1    7192
# 2    2834
# 3     859
# 4       1
# Name: weather, dtype: int64

# %%
plt.hist(df['temp'],bins=100)
plt.show()

# %%
df['holiday'].value_counts()
# Out:
# 0    10575
# 1      311
# Name: holiday, dtype: int64

# %%
df['workingday'].value_counts()
# Out:
# 1    7412
# 0    3474
# Name: workingday, dtype: int64

# %%
plt.hist(df['windspeed'],bins=100)
plt.show()

# %%
plt.scatter(df['humidity'],df['windspeed'],color='red')
plt.xlabel('humidity')
plt.ylabel('windspeed')
plt.show()

# %% [markdown]
# # **DATE SPLITTING** IMPORTANT

# %% [markdown]
# Creating a sepearate column for date and hour

# %%
df['date']=df.datetime.apply(lambda x : x.split()[0])
df['hour']=df.datetime.apply(lambda x : x.split()[1].split(':')[0])

# %%
import calendar
from datetime import datetime

# %%
df["weekday"] = df.date.apply(lambda dateString : calendar.day_name[datetime.strptime(dateString,"%Y-%m-%d").weekday()]) #weekday() returm a int

# %%
df["month"]=df.date.apply(lambda x:calendar.month_name[datetime.strptime(x,"%Y-%m-%d").month])  #month() is not the format only month

# %%
df=df.drop(['datetime'],axis='columns')

# %% [markdown]
# REORDERING COLUMNS

# %%
df=df[['date','month','weekday','hour','season','holiday','workingday','weather','temp',	'atemp',	'humidity',	'windspeed',	'casual',	'registered',	'count']]
df

# %%
get_dummies_for_season=pd.get_dummies(df['season'])

# %%
get_dummies_for_season.columns=['spring','summer','fall','winter' ]

# %%
get_dummies_for_season

# %%
df

# %% [markdown]
# Mapping is not requiures but if needed it can be done like this

# %% [markdown]
# # **DO NOT EXECUTE THIS CODE**

# %%
df['season']=df['season'].map( {1:'spring', 2:'summer', 3:'fall', 4: 'winter'} )  #https://www.geeksforgeeks.org/python-map-function/

# %% [markdown]
# # ***CONTINUE HERE***

# %%
get_dummies_for_month=pd.get_dummies(df['month'])
get_dummies_for_days=pd.get_dummies(df['weekday'])
get_dummies_for_weather=pd.get_dummies(df['weather'])
get_dummies_for_workingday=pd.get_dummies(df['workingday'])
get_dummies_for_holiday=pd.get_dummies(df['holiday'])

# %%
get_dummies_for_weather.columns=['Clear_clouds','Mist_Cloudy','Light_Snowrain','Heavy_Rain_and_Ice_Pallets']

# %%
get_dummies_for_weather

# %%
get_dummies_for_workingday.columns=['Non_Working_day','Working_day']

# %%
get_dummies_for_holiday.columns=['Holiday','Non_Holiday']

# %%
df=pd.concat([df,get_dummies_for_month,get_dummies_for_days,get_dummies_for_weather,get_dummies_for_workingday,get_dummies_for_holiday,get_dummies_for_season],axis='columns')

# %%
df=df.drop(['month','weekday','season','holiday','workingday','weather'],axis='columns')

# %%
df=df[['date','January','February','March','April','May','June','July','August','September','October','November','December','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday','hour','spring','summer','fall','winter','Holiday','Non_Holiday','Non_Working_day','Working_day','Clear_clouds','Mist_Cloudy','Light_Snowrain','Heavy_Rain_and_Ice_Pallets','temp','atemp','humidity','windspeed','casual','registered','count']]
df

# %%
q=df.drop(['count','date','registered','casual'],axis='columns')
t=df['count']

# %%
d=list(df.columns)
print(len(d)-2)
# Out:
# 38

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier() #n_estimators is not necessary but can be used to improve the number of trees in the forest
model.fit(q,t)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers

#plot graph of feature importances for better visualization

plt.figure(figsize=(10,10))
feat_importances=pd.Series(model.feature_importances_, index=q.columns)
print(feat_importances)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [2.39885164e-03 2.95192957e-03 2.78140565e-03 3.95173737e-03
#  4.89394618e-03 3.59788755e-03 3.22600620e-03 2.83906258e-03
#  2.83280985e-03 3.55745159e-03 3.93112708e-03 3.62446113e-03
#  1.25606755e-02 1.11195184e-02 1.26724166e-02 1.17877372e-02
#  1.20113297e-02 5.66004868e-03 6.20606909e-03 2.51465007e-01
#  1.88981218e-03 2.84627572e-03 2.03483242e-03 2.48005919e-03
#  1.27397452e-03 1.24786181e-03 1.83640372e-03 2.49729796e-03
#  1.48876692e-02 1.47933324e-02 7.11689223e-03 6.57342875e-05
#  1.23981788e-01 1.26660586e-01 1.56064521e-01 1.76253481e-01]
# January                       0.002399
# February                      0.002952
# March                         0.002781
# April                         0.003952
# May                           0.004894
# June                          0.003598
# July                          0.003226
# August                        0.002839
# September                     0.002833
# October                       0.003557
# ...

# %%
from sklearn.ensemble import ExtraTreesClassifier

model=ExtraTreesClassifier()
model.fit(q,t)
print(model.feature_importances_)


plt.figure(figsize=(10,10))
feat_importances=pd.Series(model.feature_importances_,index=q.columns)
print(feat_importances)
feat_importances.nsmallest(10).plot(kind='barh')
plt.show()
# Out:
# [3.16160479e-03 3.39742611e-03 3.17876927e-03 4.01786943e-03
#  4.38202841e-03 3.17863302e-03 2.85338072e-03 2.68854404e-03
#  2.66448899e-03 3.24927051e-03 4.40072300e-03 3.87894880e-03
#  1.31096641e-02 1.27957167e-02 1.33101518e-02 1.28532956e-02
#  1.15736817e-02 5.81349248e-03 5.57743112e-03 2.49289116e-01
#  1.72357192e-03 2.71640797e-03 1.84043254e-03 2.53604003e-03
#  1.28864503e-03 1.15208781e-03 2.74546440e-03 2.32134386e-03
#  1.59757712e-02 1.53199770e-02 7.06996036e-03 3.72980910e-05
#  1.25106031e-01 1.25745775e-01 1.55118694e-01 1.73928264e-01]
# January                       0.003162
# February                      0.003397
# March                         0.003179
# April                         0.004018
# May                           0.004382
# June                          0.003179
# July                          0.002853
# August                        0.002689
# September                     0.002664
# October                       0.003249
# ...

# %%
df
# Out:
#              date  January  February  ...  casual  registered  count
# 0      2011-01-01        1         0  ...       3          13     16
# 1      2011-01-01        1         0  ...       8          32     40
# 2      2011-01-01        1         0  ...       5          27     32
# 3      2011-01-01        1         0  ...       3          10     13
# 4      2011-01-01        1         0  ...       0           1      1
# 5      2011-01-01        1         0  ...       0           1      1
# 6      2011-01-01        1         0  ...       2           0      2
# 7      2011-01-01        1         0  ...       1           2      3
# 8      2011-01-01        1         0  ...       1           7      8
# 9      2011-01-01        1         0  ...       8           6     14
# 10     2011-01-01        1         0  ...      12          24     36
# 11     2011-01-01        1         0  ...      26          30     56
# 12     2011-01-01        1         0  ...      29          55     84
# ...

# %%
from scipy.stats.stats import pearsonr
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

min_max_scaler=preprocessing.MinMaxScaler()

X=df[['temp','atemp','humidity','windspeed']]
y=df.iloc[:,-1]

y=np.array(y)
scores=[]
columns=[]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in X.columns:
  columns.append(i)
  tempx=np.array(df[i])
  temp2x=np.reshape(tempx,(-1,1))
  X_scaled=min_max_scaler.fit_transform(temp2x)   #Used to normalize the data column. https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html

  df_normalized=pd.DataFrame(X_scaled)
  df_normalized=np.array(df_normalized)

  df_normalized2=df_normalized.flatten()
  score=pearsonr(df_normalized2,y)
  scores.append(score[0])

# %%
scores
b=scores.index(x)
print(columns[b])

# %%
X

# %%
import numpy as np
from sklearn import preprocessing

min_max_scaler=preprocessing.MinMaxScaler(feature_range=(0,1))


for i in X.columns:
  tempx=np.array(df[i])
  temp2x=np.reshape(tempx,(-1,1))
  scaled=min_max_scaler.fit_transform(temp2x)
  
  df[i]=scaled

# %%
df
# Out:
#              date  January  February  ...  casual  registered  count
# 0      2011-01-01        1         0  ...       3          13     16
# 1      2011-01-01        1         0  ...       8          32     40
# 2      2011-01-01        1         0  ...       5          27     32
# 3      2011-01-01        1         0  ...       3          10     13
# 4      2011-01-01        1         0  ...       0           1      1
# 5      2011-01-01        1         0  ...       0           1      1
# 6      2011-01-01        1         0  ...       2           0      2
# 7      2011-01-01        1         0  ...       1           2      3
# 8      2011-01-01        1         0  ...       1           7      8
# 9      2011-01-01        1         0  ...       8           6     14
# 10     2011-01-01        1         0  ...      12          24     36
# 11     2011-01-01        1         0  ...      26          30     56
# 12     2011-01-01        1         0  ...      29          55     84
# ...

# %%
X=df.drop(['date','count','Heavy_Rain_and_Ice_Pallets','casual','registered'],axis='columns')
y=df['count']

# %%
X.columns
# Out:
# Index(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December', 'Monday',
#        'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday',
#        'hour', 'spring', 'summer', 'fall', 'winter', 'Holiday', 'Non_Holiday',
#        'Non_Working_day', 'Working_day', 'Clear_clouds', 'Mist_Cloudy',
#        'Light_Snowrain', 'temp', 'atemp', 'humidity', 'windspeed'],
#       dtype='object')

# %%
print(X.shape)
print(X.columns)
# Out:
# (6493, 4)
# Index(['temp', 'atemp', 'humidity', 'windspeed'], dtype='object')

# %% [markdown]
# # **MACHINE LEARNING MODELS**

# %% [markdown]
# **LINEAR REGRESSION**

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.metrics import accuracy_score
from sklearn import model_selection

# %%
from sklearn.model_selection import train_test_split

scores=[]
for i in range(0,50):
  X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
  model.fit(X_train,y_train)
  pred=model.predict(X_test)
  f=accuracy_score(y_test,pred)
  scores.append(f)

# %%
fold = model_selection.KFold(n_splits=10)
model = LinearRegression()
scoring = 'r2'
results = model_selection.cross_val_score(model, X_train, y_train, cv=50, scoring=scoring)

# %%
results

# %%
len(results)
# Out:
# 50

# %%
print(sum(results)/len(results))
# Out:
# 0.3502906354309131

# %% [markdown]
# **RANDOM FOREST REGRESSOR**

# %%
from sklearn.ensemble import RandomForestRegressor
rfModel = RandomForestRegressor(n_estimators=10)


scoring = 'r2'
results2 = model_selection.cross_val_score(rfModel, X_train, y_train, cv=50, scoring=scoring)

# %%
rfModel.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
len(results2)
# Out:
# 50

# %%
print(sum(results2)/len(results2))
# Out:
# 0.8489606288551101

# %% [markdown]
#  **RIDGE**

# %%
from sklearn import linear_model
ridge_m_ = linear_model.Ridge()


scoring = 'r2'
results3 = model_selection.cross_val_score(ridge_m_, X_train, y_train, cv=50, scoring=scoring)

# %%
len(results3)
# Out:
# 50

# %%
print(sum(results3)/len(results3))
# Out:
# 0.3502810973754047

# %% [markdown]
# **GradientBoostingRegressor**

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbm = GradientBoostingRegressor(n_estimators=40,alpha=0.01)

scoring = 'r2'
results5 = model_selection.cross_val_score(gbm, X, y, cv=50, scoring=scoring)

# %%
len(results5)
# Out:
# 50

# %%
print(sum(results5)/len(results5))
# Out:
# 0.7047999569046355

# %% [markdown]
# **LASSO**

# %%
from sklearn import linear_model
lasso_m_ =linear_model.Lasso()

scoring = 'r2'
results4 = model_selection.cross_val_score(lasso_m_, X_train, y_train, cv=50, scoring=scoring)

# %%
print(len(results4))
# Out:
# 50

# %%
print(sum(results4)/len(results4))
# Out:
# 0.34369434383948494

# %% [markdown]
# TESTING THE DATA

# %%
df_test=pd.read_csv('/content/test.csv')
df_test
# Out:
#                  datetime  season  holiday  ...   atemp  humidity  windspeed
# 0     2011-01-20 00:00:00       1        0  ...  11.365        56    26.0027
# 1     2011-01-20 01:00:00       1        0  ...  13.635        56     0.0000
# 2     2011-01-20 02:00:00       1        0  ...  13.635        56     0.0000
# 3     2011-01-20 03:00:00       1        0  ...  12.880        56    11.0014
# 4     2011-01-20 04:00:00       1        0  ...  12.880        56    11.0014
# 5     2011-01-20 05:00:00       1        0  ...  11.365        60    15.0013
# 6     2011-01-20 06:00:00       1        0  ...  10.605        60    15.0013
# 7     2011-01-20 07:00:00       1        0  ...  10.605        55    15.0013
# 8     2011-01-20 08:00:00       1        0  ...  10.605        55    19.0012
# 9     2011-01-20 09:00:00       1        0  ...  11.365        52    15.0013
# 10    2011-01-20 10:00:00       1        0  ...  11.365        48    19.9995
# ...

# %%
column1=df_test['datetime']

# %%
df_test['date']=df_test.datetime.apply(lambda x : x.split()[0])
df_test['hour']=df_test.datetime.apply(lambda x : x.split()[1].split(':')[0])

# %%
from datetime import datetime
import calendar

# %%
df_test['weekday']=df_test.date.apply(lambda x: calendar.day_name[datetime.strptime(x,'%Y-%m-%d').weekday()])

# %%
df_test

# %%
df_test['month']=df_test.date.apply(lambda x: calendar.month_name[datetime.strptime(x,'%Y-%m-%d').month])

# %%
df_test=df_test.drop(['datetime'],axis='columns')

# %%
df_test
# Out:
#       season  holiday  workingday  weather  ...        date  hour   weekday     month
# 0          1        0           1        1  ...  2011-01-20    00  Thursday   January
# 1          1        0           1        1  ...  2011-01-20    01  Thursday   January
# 2          1        0           1        1  ...  2011-01-20    02  Thursday   January
# 3          1        0           1        1  ...  2011-01-20    03  Thursday   January
# 4          1        0           1        1  ...  2011-01-20    04  Thursday   January
# 5          1        0           1        1  ...  2011-01-20    05  Thursday   January
# 6          1        0           1        1  ...  2011-01-20    06  Thursday   January
# 7          1        0           1        1  ...  2011-01-20    07  Thursday   January
# 8          1        0           1        1  ...  2011-01-20    08  Thursday   January
# 9          1        0           1        2  ...  2011-01-20    09  Thursday   January
# ...

# %%
get_dummies_for_testseason=pd.get_dummies(df_test['season'])
get_dummies_for_testmonth=pd.get_dummies(df_test['month'])
get_dummies_for_testdays=pd.get_dummies(df_test['weekday'])
get_dummies_for_testweather=pd.get_dummies(df_test['weather'])
get_dummies_for_testworkingday=pd.get_dummies(df_test['workingday'])
get_dummies_for_testholiday=pd.get_dummies(df_test['holiday'])

# %%
get_dummies_for_testseason.columns=['spring','summer','fall','winter' ]
get_dummies_for_testweather.columns=['Clear_clouds','Mist_Cloudy','Light_Snowrain','Heavy_Rain_and_Ice_Pallets']

# %%
get_dummies_for_testworkingday.columns=['Non_Working_day','Working_day']
get_dummies_for_testholiday.columns=['Holiday','Non_Holiday']

# %%
df_test=pd.concat([df_test,get_dummies_for_testmonth,get_dummies_for_testdays,get_dummies_for_testweather,get_dummies_for_testworkingday,get_dummies_for_testholiday,get_dummies_for_testseason],axis='columns')
df_test
# Out:
#       season  holiday  workingday  weather  ...  spring  summer  fall  winter
# 0          1        0           1        1  ...       1       0     0       0
# 1          1        0           1        1  ...       1       0     0       0
# 2          1        0           1        1  ...       1       0     0       0
# 3          1        0           1        1  ...       1       0     0       0
# 4          1        0           1        1  ...       1       0     0       0
# 5          1        0           1        1  ...       1       0     0       0
# 6          1        0           1        1  ...       1       0     0       0
# 7          1        0           1        1  ...       1       0     0       0
# 8          1        0           1        1  ...       1       0     0       0
# 9          1        0           1        2  ...       1       0     0       0
# 10         1        0           1        1  ...       1       0     0       0
# ...

# %%
df_test=df_test.drop(['season','holiday','workingday','weather','Heavy_Rain_and_Ice_Pallets','date'],axis='columns')

# %%
df_test=df_test[['January','February','March','April','May','June','July','August','September','October','November','December','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday','hour','spring','summer','fall','winter','Holiday','Non_Holiday','Non_Working_day','Working_day','Clear_clouds','Mist_Cloudy','Light_Snowrain','temp','atemp','humidity','windspeed']]
df_test
# Out:
#       January  February  March  April  ...   temp   atemp  humidity  windspeed
# 0           1         0      0      0  ...  10.66  11.365        56    26.0027
# 1           1         0      0      0  ...  10.66  13.635        56     0.0000
# 2           1         0      0      0  ...  10.66  13.635        56     0.0000
# 3           1         0      0      0  ...  10.66  12.880        56    11.0014
# 4           1         0      0      0  ...  10.66  12.880        56    11.0014
# 5           1         0      0      0  ...   9.84  11.365        60    15.0013
# 6           1         0      0      0  ...   9.02  10.605        60    15.0013
# 7           1         0      0      0  ...   9.02  10.605        55    15.0013
# 8           1         0      0      0  ...   9.02  10.605        55    19.0012
# 9           1         0      0      0  ...   9.84  11.365        52    15.0013
# 10          1         0      0      0  ...  10.66  11.365        48    19.9995
# ...

# %%
from scipy.stats.stats import pearsonr
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

min_max_scaler=preprocessing.MinMaxScaler()

X=df_test[['temp','atemp','humidity','windspeed']]

# %%
X

# %%
import numpy as np
from sklearn import preprocessing

min_max_scaler=preprocessing.MinMaxScaler(feature_range=(0,1))


for i in X.columns:
  tempx=np.array(df_test[i])
  temp2x=np.reshape(tempx,(-1,1))
  scaled=min_max_scaler.fit_transform(temp2x)
  
  df_test[i]=scaled

# %%
df_test
# Out:
#       January  February  March  April  ...      temp   atemp  humidity  windspeed
# 0           1         0      0      0  ...  0.250000  0.2273  0.476190   0.464346
# 1           1         0      0      0  ...  0.250000  0.2727  0.476190   0.000000
# 2           1         0      0      0  ...  0.250000  0.2727  0.476190   0.000000
# 3           1         0      0      0  ...  0.250000  0.2576  0.476190   0.196458
# 4           1         0      0      0  ...  0.250000  0.2576  0.476190   0.196458
# 5           1         0      0      0  ...  0.229167  0.2273  0.523810   0.267887
# 6           1         0      0      0  ...  0.208333  0.2121  0.523810   0.267887
# 7           1         0      0      0  ...  0.208333  0.2121  0.464286   0.267887
# 8           1         0      0      0  ...  0.208333  0.2121  0.464286   0.339316
# 9           1         0      0      0  ...  0.229167  0.2273  0.428571   0.267887
# ...

# %%
print(df_test.shape)
print(df_test.columns)
# Out:
# (6493, 35)
# Index(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December', 'Monday',
#        'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday',
#        'hour', 'spring', 'summer', 'fall', 'winter', 'Holiday', 'Non_Holiday',
#        'Non_Working_day', 'Working_day', 'Clear_clouds', 'Mist_Cloudy',
#        'Light_Snowrain', 'temp', 'atemp', 'humidity', 'windspeed'],
#       dtype='object')

# %%
prediction=rfModel.predict(df_test)

# %%
type(prediction)
# Out:
# numpy.ndarray

# %%
import math

final_prediction=np.ceil(prediction)

# %%
final_prediction
# Out:
# array([18.,  5.,  4., ..., 74., 52., 62.])

# %%
import csv
with open('bikepredict.csv', 'wb') as csvfile:
    filewriter = csv.writer(csvfile, delimiter=',',quotechar='|', quoting=csv.QUOTE_MINIMAL)

# %%
final_prediction=pd.DataFrame(prediction)

# %%
final_csv=pd.concat([final_prediction,column1],axis='columns')

# %%
final_csv.columns=['count','datetime']

# %%
final_csv['count']=final_csv['count'].astype(int)

# %%
final_csv.shape
# Out:
# (6493, 2)

# %%
pd.DataFrame(final_csv).to_csv('bikepredict.csv')

# %%
g=pd.read_csv('/content/bikepredict.csv')
g
# Out:
#       Unnamed: 0  count             datetime
# 0              0   17.3  2011-01-20 00:00:00
# 1              1    4.2  2011-01-20 01:00:00
# 2              2    4.0  2011-01-20 02:00:00
# 3              3    3.4  2011-01-20 03:00:00
# 4              4    3.4  2011-01-20 04:00:00
# 5              5   13.8  2011-01-20 05:00:00
# 6              6   60.7  2011-01-20 06:00:00
# 7              7  127.2  2011-01-20 07:00:00
# 8              8  272.8  2011-01-20 08:00:00
# 9              9  131.4  2011-01-20 09:00:00
# 10            10   99.2  2011-01-20 10:00:00
# 11            11   76.3  2011-01-20 11:00:00
# 12            12   93.7  2011-01-20 12:00:00
# 13            13   83.7  2011-01-20 13:00:00
# 14            14   86.6  2011-01-20 14:00:00
# 15            15  101.5  2011-01-20 15:00:00
# 16            16  107.3  2011-01-20 16:00:00
# 17            17  240.7  2011-01-20 17:00:00
# 18            18  195.1  2011-01-20 18:00:00
# 19            19  206.7  2011-01-20 19:00:00
# ...

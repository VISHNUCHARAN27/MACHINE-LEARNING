# %% [markdown]
# <a href="https://colab.research.google.com/github/VISHNUCHARAN27/MACHINE-LEARNING/blob/master/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip titanic.zip
# Out:
# Archive:  titanic.zip
#   inflating: train.csv
#   inflating: test.csv
#   inflating: gender_submission.csv

# %%
import pandas as pd

df=pd.read_csv('/content/train.csv')

print(df.shape)
print(df.count())
# Out:
# (891, 12)
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %% [markdown]
# We check the number of survived and deceased rate

# %%
x=df.Survived.value_counts() 
x
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# We are visualising the number of people deceased which is 0 and number of people survived which is  1.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,6))
x=df.Survived.value_counts()    # value_counts Return a Series containing counts of unique values.
x.plot(kind='bar',alpha=0.5,color='blue')   #alpha is a float value between 0-1 which determines the darkness of the image. 
plt.show()

# %% [markdown]
# To show the percentage the graph in terms of percentage we use

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,6))
x=df.Survived.value_counts(normalize=True)    # value_counts Return a Series containing counts of unique values.
x.plot(kind='bar',alpha=0.5,color='blue')   #alpha is a float value between 0-1 which determines the darkness of the image. 
plt.show()

# %% [markdown]
# Now we check the relationship between age and survivor rate

# %%
plt.title('Age wrt Survive')
plt.scatter(df.Survived,df.Age,alpha=0.1)
plt.xlabel('Survived')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %% [markdown]
# We use subplot to visualize graphs all in one

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,6))

plt.subplot2grid((2,3),(0,0))   # Create an axis at specific location inside a regular grid.
plt.title('Survival rate')
x=df.Survived.value_counts(normalize=True)    # value_counts Return a Series containing counts of unique values.
x.plot(kind='bar',alpha=0.5,color='blue')   #alpha is a float value between 0-1 which determines the darkness of the image. 


plt.subplot2grid((2,3),(0,1))
plt.title('Age wrt Survive')
plt.scatter(df.Survived,df.Age,alpha=0.1)
plt.xlabel('Survived')
plt.ylabel('Age')

plt.show()

# %% [markdown]
# We check the Pclass of the passengers

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,6))

plt.subplot2grid((2,3),(0,0))
plt.title('Survival rate')
x=df.Survived.value_counts(normalize=True)    # value_counts Return a Series containing counts of unique values.
x.plot(kind='bar',alpha=0.5,color='blue')   #alpha is a float value between 0-1 which determines the darkness of the image. 


plt.subplot2grid((2,3),(0,1))
plt.title('Age wrt Survive')
plt.scatter(df.Survived,df.Age,alpha=0.1)
plt.xlabel('Survived')
plt.ylabel('Age')

plt.subplot2grid((2,3),(0,2))
plt.title('Class rate')
z=df.Pclass.value_counts(normalize=True)    # value_counts Return a Series containing counts of unique values.
z.plot(kind='bar',alpha=0.5,color='blue')



plt.show()

# %% [markdown]
# Now we check the correlation of class wrt age of the passengers

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,6))

plt.subplot2grid((2,3),(0,0))
plt.title('Survival rate')
x=df.Survived.value_counts(normalize=True)    # value_counts Return a Series containing counts of unique values.
x.plot(kind='bar',alpha=0.5,color='blue')   #alpha is a float value between 0-1 which determines the darkness of the image. 


plt.subplot2grid((2,3),(0,1))
plt.title('Age wrt Survive')
plt.scatter(df.Survived,df.Age,alpha=0.1)
plt.xlabel('Survived')
plt.ylabel('Age')

plt.subplot2grid((2,3),(0,2))
plt.title('Class rate')
z=df.Pclass.value_counts(normalize=True)    # value_counts Return a Series containing counts of unique values.
z.plot(kind='bar',alpha=0.5,color='blue')

plt.subplot2grid((2,3),(1,0),colspan=2)              #colspan : int Number of columns for the axis to span downwards.
for x in [1,2,3]:
  df.Age[df.Pclass==x].plot(kind='kde')   #kde stands for kernel density estimation. https://www.homeworkhelponline.net/blog/math/tutorial-kde
  
plt.title('Class wrt Age')
plt.legend(('1st','2nd','3rd'))   #legend gives the 1st,2nd andn 3rd lines in the box 

plt.show()

# %% [markdown]
# Finally we checked the embarked

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,6))

plt.subplot2grid((2,3),(0,0))
plt.title('Survival rate')
x=df.Survived.value_counts(normalize=True)    # value_counts Return a Series containing counts of unique values.
x.plot(kind='bar',alpha=0.5,color='blue')   #alpha is a float value between 0-1 which determines the darkness of the image. 


plt.subplot2grid((2,3),(0,1))
plt.title('Age wrt Survive')
plt.scatter(df.Survived,df.Age,alpha=0.1)
plt.xlabel('Survived')
plt.ylabel('Age')

plt.subplot2grid((2,3),(0,2))
plt.title('Class rate')
z=df.Pclass.value_counts(normalize=True)    # value_counts Return a Series containing counts of unique values.
z.plot(kind='bar',alpha=0.5,color='blue')

plt.subplot2grid((2,3),(1,0),colspan=2)              #colspan : int Number of columns for the axis to span downwards.
for x in [1,2,3]:
  df.Age[df.Pclass==x].plot(kind='kde')   #kde stands for kernel density estimation. https://www.homeworkhelponline.net/blog/math/tutorial-kde
  
plt.title('Class wrt Age')
plt.legend(('1st','2nd','3rd'))   #legend gives the 1st,2nd andn 3rd lines in the box 

plt.subplot2grid((2,3),(1,2))
t=df.Embarked.value_counts(normalize=True)
t.plot(kind='bar',alpha=0.5,color='brown')

plt.show()

# %% [markdown]
# Now let us check the male and female survived

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.subplot2grid((3,5),(0,0),colspan=2)
df.Survived.value_counts(normalize=True).plot(kind='bar',alpha=0.5)
plt.title('Survived')

plt.subplot2grid((3,5),(0,2),colspan=2)
df.Survived[df.Sex=='male'].value_counts(normalize=True).plot(kind='bar',alpha=0.5)
plt.title('Male survived')

plt.subplot2grid((3,5),(1,0),colspan=2)
df.Survived[df.Sex=='female'].value_counts(normalize=True).plot(kind='bar',alpha=0.5,color='red')
plt.title('Female survived')

plt.subplot2grid((3,5),(1,2),colspan=2)
df.Sex[df.Survived==1].value_counts(normalize=True).plot(kind='bar',alpha=0.7,color='brown')
plt.title('Gender Survived')

plt.subplot2grid((3,5),(2,0),colspan=4)
for i in [1,2,3]:
  df.Survived[df.Pclass==i].plot(kind='kde')   #here value_counts does not come
plt.legend(('1st','2nd','3rd'))
plt.title('Class wrt Survived')
  
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))

plt.subplot2grid((3,5),(0,0),colspan=2)
df.Survived[(df.Sex=='male') & (df.Pclass==1)].value_counts(normalize=True).plot(kind='bar')  #Learn the difference between 'and' and & in python
plt.title('Rich Men Survived')

plt.subplot2grid((3,5),(0,2),colspan=2)
df.Survived[(df.Sex=='male') & (df.Pclass==3)].value_counts(normalize=True).plot(kind='bar')  #Learn the difference between 'and' and & in python
plt.title('Poor Men Survived')
# Out:
# Text(0.5, 1.0, 'Poor Men Survived')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))

plt.subplot2grid((3,5),(0,0),colspan=2)
df.Survived[(df.Sex=='female') & (df.Pclass==1)].value_counts(normalize=True).plot(kind='bar',color='pink')  #Learn the difference between 'and' and & in python
plt.title('Rich Women Survived')

plt.subplot2grid((3,5),(0,2),colspan=2)
df.Survived[(df.Sex=='female') & (df.Pclass==3)].value_counts(normalize=True).plot(kind='bar',color='pink')  #Learn the difference between 'and' and & in python
plt.title('Poor Women Survived')
# Out:
# Text(0.5, 1.0, 'Poor Women Survived')

# %% [markdown]
# Now we do some machine learning algorithms

# %%
import pandas as pd

train=pd.read_csv('/content/train.csv')
train['Hyp']=0
train.loc[train.Sex=='female','Hyp']=1  #In loc we pass a condition and a column to update

train['Result']=0
train.loc[train.Survived==train['Hyp'],'Result']=1    #result is enough. Gives wrong answer when given train['Result']

print(train["Result"].value_counts())
print(train["Result"].value_counts(normalize=True))
# Out:
# 1    701
# 0    190
# Name: Result, dtype: int64
# 1    0.786756
# 0    0.213244
# Name: Result, dtype: float64

# %%
def clean_data(data):
  data["Fare"]=data['Fare'].fillna(data['Fare'].dropna().median()) #Pandas dropna() method allows the user to analyze and drop Rows/Columns with Null values in different ways.
  data["Age"]=data["Age"].fillna(data["Age"].dropna().median())
  
  data.loc[data["Sex"]=="male","Sex"]=0
  data.loc[data["Sex"]=="female","Sex"]=1
  
  data["Embarked"]=data["Embarked"].fillna("S")
  
  data.loc[data["Embarked"]=="S","Embarked"]=0
  data.loc[data["Embarked"]=="C","Embarked"]=1
  data.loc[data["Embarked"]=="Q","Embarked"]=2

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

train=pd.read_csv('/content/train.csv')
clean_data(train)

# %%
import numpy as np
target=train["Survived"].values
features=train[["Pclass","Age","Sex","SibSp","Parch"]].values

target_=np.reshape(target,(-1,1))
print(target_)

# %%
import warnings
warnings.filterwarnings("ignore")   #To ignore warnings

# %%
import numpy as np
target=train["Survived"].values
features=train[["Pclass","Age","Sex","SibSp","Parch"]].values

target_=np.reshape(target,(-1,1))
classifier=LogisticRegression()
classifier_=classifier.fit(features,target_)

print(classifier_.score(features,target_))
# Out:
# 0.7934904601571269

# %% [markdown]
# Now we add more features

# %%
import numpy as np
target=train["Survived"].values
features=train[["Pclass","Age","Sex","SibSp","Parch","Embarked","Fare"]].values

target_=np.reshape(target,(-1,1))
classifier=LogisticRegression()
classifier_=classifier.fit(features,target_)

print(classifier_.score(features,target_))
# Out:
# 0.7991021324354658

# %%
import numpy as np
from sklearn import preprocessing

target=train["Survived"].values
features=train[["Pclass","Age","Sex","SibSp","Parch","Embarked","Fare"]].values

target_=np.reshape(target,(-1,1))
classifier=LogisticRegression()
classifier_=classifier.fit(features,target_)

print(classifier_.score(features,target_))

poly=preprocessing.PolynomialFeatures(degree=2)
#Generate polynomial and interaction features.Generate a new feature matrix consisting of all polynomial combinations of the features with 
#degree less than or equal to the specified degree.
#For example, if an input sample is two dimensional and of the form [a, b], the degree-2 polynomial features are [1, a, b, a^2, ab, b^2].
poly_features=poly.fit_transform(features)
classifier2=classifier.fit(poly_features,target_)

print(classifier2.score(poly_features,target_))
# Out:
# 0.7991021324354658
# 0.8327721661054994

# %%
from sklearn import tree
decision_tree=tree.DecisionTreeClassifier(random_state=1)
decision_tree_=decision_tree.fit(features,target)

print(decision_tree_.score(features,target))
# Out:
# 0.9797979797979798

# %%
from sklearn import model_selection   
scores=model_selection.cross_val_score(decision_tree,features,target,scoring='accuracy',cv=50)  #scoring determines the measurement in which we determine our accuracy.
#cv represents the number of times we need to perform. Here we  are hiding some data from the algorithm

print(scores.mean())
# Out:
# 0.7826633986928105
